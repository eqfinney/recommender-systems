# %% [markdown]
# # Charities: The Real Deal
# ## Author: Emily Quinn Finney
#
# My implementation of a content-based charity recommender system, based on the core
# functionality present in charities_toyscript.py.
#
# This notebook includes the data cleaning and exploratory analysis I used to analyze
# the Charity Navigator (CN, https://www.charitynavigator.org/) data set obtained
# from their public API.
#
# It also includes machine learning concepts I did not use in the toy data set,
# such as feature extraction.

# %%
import pandas as pd
import numpy as np
import charities_toyscript as ct

# importing pysco for faster performance
try:
    import psyco
    psyco.full()
except ImportError:
    pass

# %% [markdown]
# First let's understand what's in the data set. I have obtained a JSON file (API access implemented in api.py), which I would like to read in and visualize.

# %%
import json
charity_data = pd.read_json('cn.json')
charity_data.head(15)
# Out:
#    category cause                                        charityName  \
# 0       NaN   NaN                          VOLUNTEERS OF AMERICA INC
# 1       NaN   NaN                                      Boobies Rock!
# 2       NaN   NaN                                    Say No 2 Cancer
# 3       NaN   NaN                                   The Se7ven Group
# 4       NaN   NaN                                 26.4.26 Foundation
# 5       NaN   NaN                                  Tackle Hatred Now
# 6       NaN   NaN                   Veterans Helping Nevada Veterans
# 7       NaN   NaN                              Voice of a Child U.S.
# 8       NaN   NaN                                    Winged Warriors
# 9       NaN   NaN    Angelinos for Culture and a Healthy Environment
# 10      NaN   NaN                   Blythe Citizens for Smart Growth
# 11      NaN   NaN                                Build Barstow Smart
# 12      NaN   NaN                        Concerned Citizens of Vista
# ...

# %% [markdown]
# Unfortunately this data set is not especially rich in useful features upon which to build a recommender system. (And their premium data set has a price tag to match.) So I'm going to table this project for now, write a blog post about what I've done, and maybe come back to it if I find a data set I like better.
